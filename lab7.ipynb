# %%
import numpy as np
import pandas as pd

# %%
# !pip install ucimlrepo
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ucimlrepo import fetch_ucirepo

# %%
# !pip install kaggle
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_csv("Social_Network_Ads.csv")

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
df.shape
# Out:
# (400, 3)

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
df.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
df_filled = df.fillna(df.mean())
df_filled
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
minmax_scaler = MinMaxScaler()
minmax_data = minmax_scaler.fit_transform(df_filled)
print(minmax_data)
# Out:
# [[0.02380952 0.02962963 0.        ]
#  [0.4047619  0.03703704 0.        ]
#  [0.19047619 0.20740741 0.        ]
#  ...
#  [0.76190476 0.03703704 1.        ]
#  [0.42857143 0.13333333 0.        ]
#  [0.73809524 0.15555556 1.        ]]

# %%
df_minmax = pd.DataFrame (
     minmax_data,
     columns = df.columns
)
df_minmax.head()
# Out:
#         Age  EstimatedSalary  Purchased
# 0  0.023810         0.029630        0.0
# 1  0.404762         0.037037        0.0
# 2  0.190476         0.207407        0.0
# 3  0.214286         0.311111        0.0
# 4  0.023810         0.451852        0.0

# %%
scaler = StandardScaler()
standardized_data = scaler.fit_transform(df_filled)
print(standardized_data)
# Out:
# [[-1.78179743 -1.49004624 -0.74593581]
#  [-0.25358736 -1.46068138 -0.74593581]
#  [-1.11320552 -0.78528968 -0.74593581]
#  ...
#  [ 1.17910958 -1.46068138  1.34059793]
#  [-0.15807423 -1.07893824 -0.74593581]
#  [ 1.08359645 -0.99084367  1.34059793]]

# %%
df_standard = pd.DataFrame(standardized_data, columns=df.columns)
df_standard
# Out:
#           Age  EstimatedSalary  Purchased
# 0   -1.781797        -1.490046  -0.745936
# 1   -0.253587        -1.460681  -0.745936
# 2   -1.113206        -0.785290  -0.745936
# 3   -1.017692        -0.374182  -0.745936
# 4   -1.781797         0.183751  -0.745936
# ..        ...              ...        ...
# 395  0.797057        -0.844019   1.340598
# 396  1.274623        -1.372587   1.340598
# 397  1.179110        -1.460681   1.340598
# 398 -0.158074        -1.078938  -0.745936
# 399  1.083596        -0.990844   1.340598
#
# [400 rows x 3 columns]

# %%
test_data = np.array([[1,2,3], [4,5,6]])

# %%
test_data
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
df1 = pd.read_csv("car_sales_dataset_with_person_details.csv")

# %%
df1
# Out:
#              Brand        Model  Year     Price  Mileage   Color  \
# 0            Honda        Civic  2023  25627.20    58513   Green
# 1            Mazda       Mazda3  2000  12027.14    60990   Brown
# 2            Mazda         CX-5  2014  49194.93     1703   Green
# 3          Hyundai       Tucson  2003  11955.94    25353  Silver
# 4       Land Rover  Range Rover  2012  10910.01    76854  Orange
# ...            ...          ...   ...       ...      ...     ...
# 999995       Honda        Pilot  2013  15546.60   107099   Green
# 999996     Hyundai       Sonata  2024  52595.03   159945    Blue
# 999997      Nissan       Murano  2014  48278.62    43711    Gray
# 999998      Nissan       Sentra  2002  53124.63   101405  Yellow
# 999999     Hyundai     Santa Fe  2024  24576.49   115595   Black
#
#                   Condition First Name Last Name         Address Country
# 0       Certified Pre-Owned      Emily    Harris     456 Oak Ave  Brazil
# ...

# %%
df1.head()
df1.info()
df1.describe()
df1.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 11 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Brand       1000000 non-null  object
#  1   Model       1000000 non-null  object
#  2   Year        1000000 non-null  int64
#  3   Price       1000000 non-null  float64
#  4   Mileage     1000000 non-null  int64
#  5   Color       1000000 non-null  object
#  6   Condition   1000000 non-null  object
#  7   First Name  1000000 non-null  object
#  8   Last Name   1000000 non-null  object
#  9   Address     1000000 non-null  object
#  10  Country     1000000 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 83.9+ MB
# (1000000, 11)

# %%
df1.isnull().sum()
# Out:
# Brand         0
# Model         0
# Year          0
# Price         0
# Mileage       0
# Color         0
# Condition     0
# First Name    0
# Last Name     0
# Address       0
# Country       0
# dtype: int64

# %%
df1 = df1.dropna()

# %%
df1
# Out:
#              Brand        Model  Year     Price  Mileage   Color  \
# 0            Honda        Civic  2023  25627.20    58513   Green
# 1            Mazda       Mazda3  2000  12027.14    60990   Brown
# 2            Mazda         CX-5  2014  49194.93     1703   Green
# 3          Hyundai       Tucson  2003  11955.94    25353  Silver
# 4       Land Rover  Range Rover  2012  10910.01    76854  Orange
# ...            ...          ...   ...       ...      ...     ...
# 999995       Honda        Pilot  2013  15546.60   107099   Green
# 999996     Hyundai       Sonata  2024  52595.03   159945    Blue
# 999997      Nissan       Murano  2014  48278.62    43711    Gray
# 999998      Nissan       Sentra  2002  53124.63   101405  Yellow
# 999999     Hyundai     Santa Fe  2024  24576.49   115595   Black
#
#                   Condition First Name Last Name         Address Country
# 0       Certified Pre-Owned      Emily    Harris     456 Oak Ave  Brazil
# ...

# %%
df.dtypes
# Out:
# Age                int64
# EstimatedSalary    int64
# Purchased          int64
# dtype: object

# %%
df1 = df1.drop(['First Name', 'Last Name', 'Address'], axis=1)

# %%
df1
# Out:
#              Brand        Model  Year     Price  Mileage   Color  \
# 0            Honda        Civic  2023  25627.20    58513   Green
# 1            Mazda       Mazda3  2000  12027.14    60990   Brown
# 2            Mazda         CX-5  2014  49194.93     1703   Green
# 3          Hyundai       Tucson  2003  11955.94    25353  Silver
# 4       Land Rover  Range Rover  2012  10910.01    76854  Orange
# ...            ...          ...   ...       ...      ...     ...
# 999995       Honda        Pilot  2013  15546.60   107099   Green
# 999996     Hyundai       Sonata  2024  52595.03   159945    Blue
# 999997      Nissan       Murano  2014  48278.62    43711    Gray
# 999998      Nissan       Sentra  2002  53124.63   101405  Yellow
# 999999     Hyundai     Santa Fe  2024  24576.49   115595   Black
#
#                   Condition Country
# 0       Certified Pre-Owned  Brazil
# 1       Certified Pre-Owned   Italy
# 2       Certified Pre-Owned      UK
# 3                      Used  Mexico
# ...

# %%
df_encoded = pd.get_dummies(df1, drop_first=True)
df_encoded.head()
# Out:
#    Year     Price  Mileage  Brand_BMW  Brand_Chevrolet  Brand_Chrysler  \
# 0  2023  25627.20    58513      False            False           False
# 1  2000  12027.14    60990      False            False           False
# 2  2014  49194.93     1703      False            False           False
# 3  2003  11955.94    25353      False            False           False
# 4  2012  10910.01    76854      False            False           False
#
#    Brand_Dodge  Brand_Ford  Brand_Honda  Brand_Hyundai  ...  Condition_Used  \
# 0        False       False         True          False  ...           False
# 1        False       False        False          False  ...           False
# 2        False       False        False          False  ...           False
# 3        False       False        False           True  ...            True
# 4        False       False        False          False  ...            True
#
#    Country_Brazil  Country_Canada  Country_France  Country_Germany  \
# ...

# %%
X = df1.select_dtypes(include=['number'])

# %%
X
# Out:
#         Year     Price  Mileage
# 0       2023  25627.20    58513
# 1       2000  12027.14    60990
# 2       2014  49194.93     1703
# 3       2003  11955.94    25353
# 4       2012  10910.01    76854
# ...      ...       ...      ...
# 999995  2013  15546.60   107099
# 999996  2024  52595.03   159945
# 999997  2014  48278.62    43711
# 999998  2002  53124.63   101405
# 999999  2024  24576.49   115595
#
# [1000000 rows x 3 columns]

# %%
Y = df1.select_dtypes(include=['object'])
Y
# Out:
#              Brand        Model   Color            Condition Country
# 0            Honda        Civic   Green  Certified Pre-Owned  Brazil
# 1            Mazda       Mazda3   Brown  Certified Pre-Owned   Italy
# 2            Mazda         CX-5   Green  Certified Pre-Owned      UK
# 3          Hyundai       Tucson  Silver                 Used  Mexico
# 4       Land Rover  Range Rover  Orange                 Used     USA
# ...            ...          ...     ...                  ...     ...
# 999995       Honda        Pilot   Green                  New      UK
# 999996     Hyundai       Sonata    Blue  Certified Pre-Owned     USA
# 999997      Nissan       Murano    Gray                 Used   Italy
# 999998      Nissan       Sentra  Yellow  Certified Pre-Owned  France
# 999999     Hyundai     Santa Fe   Black                 Used   Italy
#
# [1000000 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
plt.plot(df)
plt.title("Salary")
plt.xlabel("Age")
plt.ylabel("EstimatedSalary")
plt.legend()
plt.show()
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_11128\3031264960.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
